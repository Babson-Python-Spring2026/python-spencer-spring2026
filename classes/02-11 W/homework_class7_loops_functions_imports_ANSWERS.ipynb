# %% [markdown]
# # Homework — Loops, Functions, and Imports
#
# **Graded Assignment — Read Carefully**
#
# This homework emphasizes **reasoning, prediction, and explanation**, not just producing output.
#
# ## Rules
# - Do **not** run code until instructed.
# - For every problem:
#   1. Write your **prediction**
#   2. Write a **brief explanation** (1–3 sentences)
#   3. Then run and compare
#
# Partial credit is awarded for clear reasoning, even if the prediction is incorrect.

# %% [markdown]
# ## Part A — Loops (8 problems)

# %% [markdown]
# ### Problem 1 — Accumulator with condition
# Predict the final value of `total`.
# ```python
# nums = [3, 6, 2, 5, 4]
# total = 0
# for n in nums:
#     if n % 2 == 0:
#         total += n
#     else:
#         total -= 1
# print(total)
# ```
# Explain *why*.

# %%
# Prediction: 10
# Explanation: add the evens to total subtract 1 for each negative

# %% [markdown]
# ### Problem 2 — Nested loops with dependent ranges
# Predict the exact output.
# ```python
# for i in range(1, 4):
#     for j in range(i):
#         print(i, end=" ")
#     print()
# ```

# %%
# Prediction: 
# 1
# 2 2
# 3 3 3 
# Explanation: print i the number of i times end = ' ' adds space and prevents line return

# %% [markdown]
# ### Problem 3 — Loop with early termination
# Predict the output.
# ```python
# for n in range(2, 20):
#     if n % 7 == 0:
#         print("hit", n)
#         break
#     print(n)
# ```

# %%
# Prediction:
# 2
# 3
# 4
# 5
# 6
# hit 7

# Explanation: print n until n == 7 then print hit 7 and exit loop

# %% [markdown]
# ### Problem 4 — Loop invariant
# State the loop invariant for `total` *before* predicting the output.
# ```python
# nums = [5, 1, 4, 2]
# total = 0
# for n in nums:
#     total = max(total, n)
# print(total)
# ```

# %%
# Prediction: 5
# Explanation: total holds the maximum num seen so far

# %% [markdown]
# ### Problem 5 — Off-by-one reasoning
# Predict the output.
# ```python
# count = 0
# for i in range(1, 10):
#     if i % 3 == 0:
#         count += 1
# print(count)
# ```

# %%
# Prediction: 3
# Explanation: 3, 6,  9 all divisable by 3

# %% [markdown]
# ### Problem 6 — Nested loop with break
# Predict the output.
# ```python
# for i in range(3):
#     for j in range(3):
#         if i == j:
#             break
#         print(i, j)
# ```

# %%
# Prediction:
# 1 0
# 2 0
# 2 1
# Explanation: when i == j terminate inner loop

# %% [markdown]
# ### Problem 7 — While loop with state change
# Predict the output and number of iterations.
# ```python
# x = 20
# while x > 1:
#     if x % 2 == 0:
#         x //= 2
#     else:
#         x -= 1
#     print(x)
# ```

# %%
# Prediction: 
# 10
#  5
#  4
#  2
#  1
# Explanation: else loop gets executed once

# %% [markdown]
# ### Problem 8 — Trick loop (mutation during iteration)
# Predict the final list.
# ```python
# nums = [1, 2, 3, 4]
# for i in range(len(nums)):
#     if nums[i] % 2 == 0:
#         nums[i] *= 10
# print(nums)
# ```

# %%
# Prediction: [1, 20, 3, 40]
# Explanation: mutate list when nums[i] is even

# %% [markdown]
# ## Part B — Functions (7 problems)

# %% [markdown]
# ### Problem 9 — Parameter binding
# Predict the output and explain parameter binding.
# ```python
# def f(a, b=2, c=3):
#     return a + b*10 + c*100
# print(f(1, 4))
# ```

# %%
# Prediction: 341
# Explanation: a = 1, b = 4, c = 3 ->  1 + 4 * 10 + 3 * 100 = 341

# %% [markdown]
# ### Problem 10 — Keyword vs positional
# Predict all outputs.
# ```python
# def g(x, y=5, z=7):
#     return x, y, z
# print(g(1))
# print(g(1, z=9))
# print(g(1, 9))
# ```

# %%
# Prediction: 
# 1 5 7
# 1 5 9
# 1 9 7
# Explanation: keyword arguments are used if positional values are omitted

# %% [markdown]
# ### Problem 11 — Mutable argument (mutation)
# Does the caller’s list change? Why?
# ```python
# def update(nums):
#     nums.append(99)
# a = [1, 2, 3]
# update(a)
# print(a)
# ```

# %%
# Prediction: [1,2,3,99]
# Explanation: list mutated

# %% [markdown]
# ### Problem 12 — Mutable argument (reassignment)
# Does the caller’s list change? Why?
# ```python
# def update(nums):
#     nums = nums + [99]
# a = [1, 2, 3]
# update(a)
# print(a)
# ```

# %%
# Prediction: [1, 2, 3]
# Explanation: new local variable created with assignment

# %% [markdown]
# ### Problem 13 — Default parameter trap
# Predict the outputs.
# ```python
# def add_item(item, bucket=[]):
#     bucket.append(item)
#     return bucket
# print(add_item(1))
# print(add_item(2))
# ```

# %%
# Prediction: 
# [1]
# [1, 2]
# Explanation: see class handout

# %% [markdown]
# ### Problem 14 — Return vs print
# Predict the output.
# ```python
# def h(x):
#     print(x + 1)
# result = h(5)
# print(result)
# ```

# %%
# Prediction:
# 6
# None
# Explanation: x + 1 printed but None returned

# %% [markdown]
# ### Problem 15 — Function invariant
# What invariant must hold for `total`? Predict the output.
# ```python
# def sum_positive(nums):
#     total = 0
#     for n in nums:
#         if n > 0:
#             total += n
#     return total
# print(sum_positive([-1, 2, -3, 4]))
# ```

# %%
# Prediction: 6
# Explanation: total holds the sum of even nujmbers seen so far in the loop

# %% [markdown]
# ## Part C — Imports (5 problems)

# %% [markdown]
# ### Problem 16 — Syntax vs importability
# Which lines are **valid syntax**? Which will **run successfully**? Explain.
# ```python
# from packages.utils import helper
# from packages/utils import helper
# import packages.utils
# ```

# %%
# Explanation: 1 and 3 are valid. imports require dot notation

# %% [markdown]
# ### Problem 17 — `sys.path` reasoning
# Explain why the blank entry (`''`) may appear in `sys.path` and what it represents.

# %%
# Explanation: '' indicates directory of file being run

# %% [markdown]
# ### Problem 18 — Package resolution
# Given:
# ```
# root/
#   src/
#     main.py
#   packages/
#     utils.py
# ```
# What directory must be on `sys.path` for this to work?
# ```python
# from packages import utils
# ```

# %%
# Explanation: root must be on path. Python searches sys.path for packages and with packages looks fro utils.py

# %% [markdown]
# ### Problem 19 — Incorrect path placement
# Why does adding `root/packages` to `sys.path` break this import?
# ```python
# from packages import utils
# ```

# %%
# Explanation: python now searches packages for the folder packages (packages/packages)

# %% [markdown]
# ### Problem 20 — Notebook vs `.py` anchoring
# Explain why notebooks typically use `Path.cwd()` while `.py` files use `Path(__file__)`.

# %%
# Explanation: py files automatically have __file__ variable
