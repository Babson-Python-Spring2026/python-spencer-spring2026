# %% [markdown]
# # WarmUp
#
# Each problem below requires you to write a function.
#
# **Rules:**
# - Do not print inside the function.
# - Each function must use `return`.
# - Do not add extra logic unless required.
#
# Focus on automaticity and clean return values.
#
# **NOTE**
# Before you write a function think of the following:
# <ul style="font-family: 'Courier New', monospace;">
# <li> Step 1: Should this function take any inputs?</li>
# <li> Step 2: What type should it return?</li>
# <li> Step 3: What exact value do we want returned?</li>
# <li> Step 4: What’s the smallest code that returns that value?</li></ul>
#
# you can show the expected return type in the function signature:
#
# <span style="font-family: 'Courier New', monospace;">def some_function(parameter) -> bool:</span>

# %% [markdown]
# ## 1️⃣ Return a list
# Write a function that returns a list containing the numbers 1 through 5.

# %%
def return_list():
    # TODO: return a list containing 1 through 5
    pass

# %% [markdown]
# ## 2️⃣ Return a tuple
# Write a function that returns a tuple containing three strings of your choice.

# %%
def return_tuple():
    # TODO: return a tuple of three strings
    pass

# %% [markdown]
# ## 3️⃣ Return a dictionary
# Write a function that returns a dictionary with at least three key-value pairs.

# %%
def return_dictionary():
    # TODO: return a dictionary with at least three key-value pairs
    pass

# %% [markdown]
# ## 4️⃣ Return a range converted to list
# Write a function that returns a list of numbers from 0 to 9 using range().

# %%
def return_range_list():
    # TODO: 
    pass

# %% [markdown]
# ## 5️⃣ Return a sorted version
# Write a function that takes a list as input and returns a sorted version of that list.
# Do NOT modify the original list.

# %%
def return_sorted(lst):
    # TODO: return a sorted version of lst without modifying it
    pass

# %% [markdown]
# ## 6️⃣ Return reversed list
# Write a function that takes a list and returns a reversed version of it.
# Do NOT modify the original list.

# %%
def return_reversed(lst):
    # TODO: return a reversed version of lst without modifying it
    pass

# %% [markdown]
# ## 7️⃣ Return square of input
# Write a function that takes a number and returns its square.

# %%
def return_square(x):
    # TODO: return the square of x
    pass

# %% [markdown]
# ## 8️⃣ Return boolean condition
# Write a function that takes a number and returns True if it is even, False otherwise.

# %%
def is_even(x):
    # TODO: return True if x is even, otherwise False
    pass
